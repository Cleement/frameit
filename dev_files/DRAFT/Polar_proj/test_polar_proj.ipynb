# %% [markdown]
# ## RUN

# %%
from pathlib import Path
from frameit.core.settings_class import SimulationConfig
from frameit.core.runner import FrameitRunner

import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import xarray as xr
import math

# conf = SimulationConfig.from_yaml_with_model_preset(Path("../../configs_ktests/arome_oper_batsirai.yml"))
conf = SimulationConfig.from_yaml_with_model_preset(Path("../../configs_ktests/arome_oper_belna.yml"))

# conf = SimulationConfig.from_yaml_with_model_preset(Path("../../configs_ktests/mnh_chido.yml"))
# conf = SimulationConfig.from_yaml_with_model_preset(Path("../../configs_ktests/mnh_ianos.yml"))

conf.printID()

runner = FrameitRunner(conf)
runner.run()

# %% [markdown]
# ## MesoNH

# %% [markdown]
# ### Surface vars

# %%
from frameit.viz.polar_axes import setup_geodesic_polar_ax
fig1, ax1 = plt.subplots(1,3, figsize=(16,4))
tt=2
runner.dict_collocated_crop_user['surface'].MSLP.isel(time=tt).plot.contourf(ax=ax1[0],vmin=950,vmax=1010)
runner.dict_collocated_crop_user['surface'].LE.isel(time=tt).plot.contourf(ax=ax1[1])
runner.dict_collocated_crop_user['surface'].H.isel(time=tt).plot.contourf(ax=ax1[2])
plt.tight_layout()  


fig2, ax2 = plt.subplots(1,3, figsize=(16,4),subplot_kw={'projection': 'polar'})
setup_geodesic_polar_ax(ax2)
runner.dict_polar_user['surface'].MSLP.isel(time=tt).plot.contourf(ax=ax2[0],vmin=950,vmax=1010)
runner.dict_polar_user['surface'].LE.isel(time=tt).plot.contourf(ax=ax2[1])
runner.dict_polar_user['surface'].H.isel(time=tt).plot.contourf(ax=ax2[2])
plt.tight_layout()

# %% [markdown]
# ### 3D vars

# %%
runner.dict_crop_user['level']

# %%
from frameit.viz.polar_axes import setup_geodesic_polar_ax
fig1, ax1 = plt.subplots(1,6, figsize=(20,4))
tt=2 ; lev=10
runner.dict_collocated_crop_user['level'].UT.isel(time=tt,level=lev).plot.contourf(ax=ax1[0])
runner.dict_collocated_crop_user['level'].VT.isel(time=tt,level=lev).plot.contourf(ax=ax1[1])
runner.dict_collocated_crop_user['level'].WT.isel(time=tt,level=lev).plot.contourf(ax=ax1[2])
runner.dict_collocated_crop_user['level'].THT.isel(time=tt,level=lev).plot.contourf(ax=ax1[3],vmin=298)
runner.dict_collocated_crop_user['level'].POVOT.isel(time=tt,level=lev).plot.contourf(ax=ax1[4],vmin=-10,vmax=10)
runner.dict_collocated_crop_user['level'].wind_speed.isel(time=tt,level=lev).plot.contourf(ax=ax1[5])
plt.tight_layout() 

fig2, ax2 = plt.subplots(1,6, figsize=(20,5),subplot_kw={'projection': 'polar'})
setup_geodesic_polar_ax(ax2)
runner.dict_polar_user['level'].UT.isel(time=tt,level=lev).plot.contourf(ax=ax2[0])
runner.dict_polar_user['level'].VT.isel(time=tt,level=lev).plot.contourf(ax=ax2[1])
runner.dict_polar_user['level'].WT.isel(time=tt,level=lev).plot.contourf(ax=ax2[2])
runner.dict_polar_user['level'].THT.isel(time=tt,level=lev).plot.contourf(ax=ax2[3],vmin=298)                                                                                                                                      
runner.dict_polar_user['level'].POVOT.isel(time=tt,level=lev).plot.contourf(ax=ax2[4],vmin=-10,vmax=10)                                                                                                                                    
runner.dict_polar_user['level'].wind_speed.isel(time=tt,level=lev).plot.contourf(ax=ax2[5])                                                                                                                                    
plt.tight_layout()

# %%
runner.dict_polar_user['level']

# %% [markdown]
# ## AROME

# %%
runner.dict_crop_user['heightAboveGround']

# %%
runner.dict_polar_user

# %% [markdown]
# ### Surface vars

# %%
from frameit.viz.polar_axes import setup_geodesic_polar_ax
fig1, ax1 = plt.subplots(1,3, figsize=(16,4))
tt=0
runner.dict_crop_user['surface'].prmsl.isel(time=tt).plot.contourf(ax=ax1[0])
runner.dict_crop_user['surface'].u10.isel(time=tt).plot.contourf(ax=ax1[1])
runner.dict_crop_user['surface'].v10.isel(time=tt).plot.contourf(ax=ax1[2])
plt.tight_layout()  

fig2, ax2 = plt.subplots(1,3, figsize=(16,4),subplot_kw={'projection': 'polar'})
setup_geodesic_polar_ax(ax2)
runner.dict_polar_user['surface'].prmsl.isel(time=tt).plot.contourf(ax=ax2[0])
runner.dict_polar_user['surface'].u10.isel(time=tt).plot.contourf(ax=ax2[1])
runner.dict_polar_user['surface'].v10.isel(time=tt).plot.contourf(ax=ax2[2])
plt.tight_layout()

# %% [markdown]
# ### 3D vars

# %%
from frameit.viz.polar_axes import setup_geodesic_polar_ax
fig1, ax1 = plt.subplots(1,5, figsize=(20,4))
tt=4 ; lev=3
print(runner.dict_crop_user['heightAboveGround'].heightAboveGround[lev].values)
runner.dict_crop_user['heightAboveGround'].u.isel(time=tt,heightAboveGround=lev).plot.contourf(ax=ax1[0])
runner.dict_crop_user['heightAboveGround'].v.isel(time=tt,heightAboveGround=lev).plot.contourf(ax=ax1[1])
runner.dict_crop_user['heightAboveGround'].t.isel(time=tt,heightAboveGround=lev).plot.contourf(ax=ax1[2],vmax=302)
runner.dict_crop_user['heightAboveGround'].r.isel(time=tt,heightAboveGround=lev).plot.contourf(ax=ax1[3],vmin=75,vmax=94)     
runner.dict_crop_user['heightAboveGround'].tke.isel(time=tt,heightAboveGround=lev).plot.contourf(ax=ax1[4])
plt.tight_layout() 

fig2, ax2 = plt.subplots(1,5, figsize=(20,5),subplot_kw={'projection': 'polar'})
setup_geodesic_polar_ax(ax2)
print(runner.dict_polar_user['heightAboveGround'].heightAboveGround[lev].values)
runner.dict_polar_user['heightAboveGround'].u.isel(time=tt,heightAboveGround=lev).plot.contourf(ax=ax2[0])
runner.dict_polar_user['heightAboveGround'].v.isel(time=tt,heightAboveGround=lev).plot.contourf(ax=ax2[1])
runner.dict_polar_user['heightAboveGround'].t.isel(time=tt,heightAboveGround=lev).plot.contourf(ax=ax2[2],vmax=302)
runner.dict_polar_user['heightAboveGround'].r.isel(time=tt,heightAboveGround=lev).plot.contourf(ax=ax2[3],vmin=75,vmax=94)                                                                                                                                     
runner.dict_polar_user['heightAboveGround'].tke.isel(time=tt,heightAboveGround=lev).plot.contourf(ax=ax2[4])                                                                                                                                    
plt.tight_layout()

# %%
from frameit.viz.polar_axes import setup_geodesic_polar_ax
fig1, ax1 = plt.subplots(1, figsize=(6,6))
tt=3 ; lev=3
runner.dict_crop_user['heightAboveGround'].wind_speed.isel(time=tt,heightAboveGround=lev).plot.contourf()

fig2, ax2 = plt.subplots(1, figsize=(6,6),subplot_kw={'projection': 'polar'})
setup_geodesic_polar_ax(ax2)
runner.dict_polar_user['heightAboveGround'].wind_speed.isel(time=tt,heightAboveGround=lev).plot.contourf()

# %%
from frameit.viz.polar_axes import setup_geodesic_polar_ax
fig1, ax1 = plt.subplots(1,5, figsize=(20,4))
tt=5 ; lev=750
runner.dict_crop_user['heightAboveGround'].u.isel(time=tt).sel(heightAboveGround=lev).plot.contourf(ax=ax1[0])
runner.dict_crop_user['heightAboveGround'].v.isel(time=tt).sel(heightAboveGround=lev).plot.contourf(ax=ax1[1])
runner.dict_crop_user['heightAboveGround'].t.isel(time=tt).sel(heightAboveGround=lev).plot.contourf(ax=ax1[2],vmax=302)
runner.dict_crop_user['heightAboveGround'].r.isel(time=tt).sel(heightAboveGround=lev).plot.contourf(ax=ax1[3],vmin=75,vmax=94)     
runner.dict_crop_user['heightAboveGround'].tke.isel(time=tt).sel(heightAboveGround=lev).plot.contourf(ax=ax1[4])
plt.tight_layout() 

fig2, ax2 = plt.subplots(1,5, figsize=(20,5),subplot_kw={'projection': 'polar'})
setup_geodesic_polar_ax(ax2)
runner.dict_polar_user['heightAboveGround'].u.isel(time=tt).sel(heightAboveGround=lev).plot.contourf(ax=ax2[0])
runner.dict_polar_user['heightAboveGround'].v.isel(time=tt).sel(heightAboveGround=lev).plot.contourf(ax=ax2[1])
runner.dict_polar_user['heightAboveGround'].t.isel(time=tt).sel(heightAboveGround=lev).plot.contourf(ax=ax2[2],vmax=302)
runner.dict_polar_user['heightAboveGround'].r.isel(time=tt).sel(heightAboveGround=lev).plot.contourf(ax=ax2[3],vmin=75,vmax=94)                                                                                                                                     
runner.dict_polar_user['heightAboveGround'].tke.isel(time=tt).sel(heightAboveGround=lev).plot.contourf(ax=ax2[4])                                                                                                                                    
plt.tight_layout()

# %%
from frameit.viz.polar_axes import setup_geodesic_polar_ax
fig1, ax1 = plt.subplots(1,2, figsize=(12,4))
tt=5 ; lev=2
runner.dict_crop_user['isobaricInhPa'].u.isel(time=tt,isobaricInhPa=lev).plot.contourf(ax=ax1[0])
runner.dict_crop_user['isobaricInhPa'].v.isel(time=tt,isobaricInhPa=lev).plot.contourf(ax=ax1[1])

plt.tight_layout() 

fig2, ax2 = plt.subplots(1,2, figsize=(12,5),subplot_kw={'projection': 'polar'})
setup_geodesic_polar_ax(ax2)
runner.dict_polar_user['isobaricInhPa'].u.isel(time=tt,isobaricInhPa=lev).plot.contourf(ax=ax2[0])
runner.dict_polar_user['isobaricInhPa'].v.isel(time=tt,isobaricInhPa=lev).plot.contourf(ax=ax2[1])
